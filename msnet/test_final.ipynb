# %%
import torch
import pandas as pd
import numpy as np
from model import Model
from transformers import AutoTokenizer
import stanza
from copy import deepcopy
from transformers import pipeline
import json
import zeyrek
import nltk
from zemberek import (
    TurkishSentenceNormalizer,
    TurkishSentenceExtractor,
    TurkishMorphology,
    TurkishSpellChecker
)

morphology = TurkishMorphology.create_with_defaults()
normalizer = TurkishSentenceNormalizer(morphology)
extractor = TurkishSentenceExtractor()
spell_checker = TurkishSpellChecker(morphology)
from nltk.corpus import stopwords
import re
import nltk
nltk.download('stopwords')
stops = set(stopwords.words('turkish'))

pipe = pipeline("ner", model="51la5/roberta-large-NER", aggregation_strategy="simple")
# Out:
# 2024-08-08 20:28:59,742 - zemberek.morphology.turkish_morphology - INFO
# Msg: TurkishMorphology instance initialized in 6.42556619644165
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/musasina/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Some weights of the model checkpoint at 51la5/roberta-large-NER were not used when initializing XLMRobertaForTokenClassification: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# - This IS expected if you are initializing XLMRobertaForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing XLMRobertaForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# /home/musasina/anaconda3/envs/teknofest/lib/python3.11/site-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(

# %%
def remove_punc(text:str) -> list:
    import string
    text = text.replace("'"," ")
    texts = extractor.from_paragraph(text)
    
    for i,sentence in enumerate(texts):
        for punc in string.punctuation:
            texts[i] = sentence.replace(punc,"")
    
    return texts

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
model_1 = Model()
model_1.load_state_dict(torch.load("/home/musasina/Desktop/projects/teknofest/msnet/model.pth",map_location=torch.device('cpu'))["model_state_dict"])
tokenizer = AutoTokenizer.from_pretrained("dbmdz/bert-base-turkish-cased")
tokenizer.padding_side = "left"
tokenizer.pad_token = tokenizer.eos_token
tokenizer.add_special_tokens({'pad_token': '[PAD]'})
# Out:
# If you want to use `BertLMHeadModel` as a standalone, add `is_decoder=True.`
# /tmp/ipykernel_42941/3250319364.py:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model_1.load_state_dict(torch.load("/home/musasina/Desktop/projects/teknofest/msnet/model.pth",map_location=torch.device('cpu'))["model_state_dict"])
# 0

# %%
sentiment_map_model_1 = {1: "nötr", 0: "olumsuz", 2: "olumlu"}

# %%
def get_sentiment(text: str) -> str:
    # Model 1 prediction
    tokens_sentence = tokenizer([text], max_length=128, padding="max_length", truncation=True, return_tensors="pt").to(device)
    with torch.inference_mode():
        output_sentence = model_1(tokens_sentence["input_ids"].view(1,-1))
    sentence_sentiment = sentiment_map_model_1[output_sentence.argmax(dim=1).item()]
    return sentence_sentiment

# %%
def predict(item):
    texts = remove_punc(deepcopy(item))
    results = []
    indexes = {}
    entity_list = []
    for text in texts:
        sent = get_sentiment(text)
        entities = pipe(text)
        for entity_dict in entities:
            entity_list.append(entity_dict["word"])
        for entity in entity_list:
            if entity in text:
                indexes[entity] = sent
    

    
    for entity,sent in indexes.items():
        results.append({
            "entity": entity,
            "entity_sentiment": sent,
        })
    
    return {
        "entity_list":entity_list,
        "results": results
    }

# %%
def test_model_with_excel():
    # Read the Excel file
    df = pd.read_excel('/home/musasina/Desktop/projects/teknofest/filtered_excel_file.xlsx')
    
    # Initialize counters
    total_entities = 0
    correct_entities = 0
    correct_sentiments = 0

    # Iterate through each row in the Excel file
    for index, row in df.iterrows():
        input_text = row['Generated Text']
        expected_output = json.loads(row['Output JSON'])
        
        # Get the model's prediction
        model_output = predict(input_text)
        
        # Create dictionaries for easy lookup
        expected_results = {item['entity']: item['sentiment'] for item in expected_output['results']}
        predicted_results = {item['entity']: item['entity_sentiment'] for item in model_output['results']}
        
        # Compare entities and sentiments
        for entity, expected_sentiment in expected_results.items():
            total_entities += 1
            
            for predicted_entity in predicted_results.keys():
                if entity in predicted_entity:
                    correct_entities += 1
                    
                    if predicted_results[predicted_entity] == expected_sentiment:
                        correct_sentiments += 1
                    
                    break
            
            print(f"Input: {input_text}")
            print(f"Entity: {entity}")
            print(f"Expected Sentiment: {expected_sentiment}")
            print(f"Predicted Sentiment: {predicted_results.get(predicted_entity, 'Not found')}")
            print("-----")
    
    # Calculate accuracy
    entity_accuracy = correct_entities / total_entities if total_entities > 0 else 0
    sentiment_accuracy = correct_sentiments / total_entities if total_entities > 0 else 0
    
    print(f"Total Entities: {total_entities}")
    print(f"Correct Entities: {correct_entities}")
    print(f"Correct Sentiments: {correct_sentiments}")
    print(f"Entity Recognition Accuracy: {entity_accuracy:.2%}")
    print(f"Sentiment Analysis Accuracy: {sentiment_accuracy:.2%}")

# %%
test_model_with_excel()
# Out:
# We strongly recommend passing in an `attention_mask` since your input_ids may be padded. See https://huggingface.co/docs/transformers/troubleshooting#incorrect-output-when-padding-tokens-arent-masked.
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# Input: Hepsiburada'ya deneyimim nötr kaldı. Önce Amazon Türkiye'ye geçtim. Elektronik ürünlerini severek siparıs verdim, indirim kuponları da sıkıydı. Hepsiburada'ya da ev eşyaları fiyatından sonra memnun kaldım, hızlının teslimatlarıyla.
# Entity: Hepsiburada
# Expected Sentiment: nötr
# Predicted Sentiment: olumlu
# -----
# Input: Hepsiburada'ya deneyimim nötr kaldı. Önce Amazon Türkiye'ye geçtim. Elektronik ürünlerini severek siparıs verdim, indirim kuponları da sıkıydı. Hepsiburada'ya da ev eşyaları fiyatından sonra memnun kaldım, hızlının teslimatlarıyla.
# Entity: Amazon Türkiye
# Expected Sentiment: olumlu
# Predicted Sentiment: nötr
# -----
# Input: GittiGidiyor'da ev eşyaları aldım ama güvenli ödeme hizmeti dışında bir şey beğenmedim, ürünler beklediğim gibi değildi. Çiçeksepeti'den spor malzemeleri aldım ve hızlı teslimat gerçekten etkileyiciydi, memnun kaldım.
# Entity: GittiGidiyor
# Expected Sentiment: olumsuz
# Predicted Sentiment: olumsuz
# -----
# Input: GittiGidiyor'da ev eşyaları aldım ama güvenli ödeme hizmeti dışında bir şey beğenmedim, ürünler beklediğim gibi değildi. Çiçeksepeti'den spor malzemeleri aldım ve hızlı teslimat gerçekten etkileyiciydi, memnun kaldım.
# Entity: Çiçeksepeti
# Expected Sentiment: olumlu
# Predicted Sentiment: olumlu
# -----
# Input: Sek'in dondurması beklentilerimi karşılamadı, kalite kontrolü yetersizdi. Eti'nin meyve suyu online siparişim sorunsuz teslim edildi. Pınar'ın özel üretim bisküvisi lezzet açısından hayal kırıklığıydı. Torku'nun çikolatası online siparişimle ilgili herhangi bir sorun yaşamadım.
# Entity: Sek
# Expected Sentiment: olumsuz
# Predicted Sentiment: olumlu
# -----
# Input: Sek'in dondurması beklentilerimi karşılamadı, kalite kontrolü yetersizdi. Eti'nin meyve suyu online siparişim sorunsuz teslim edildi. Pınar'ın özel üretim bisküvisi lezzet açısından hayal kırıklığıydı. Torku'nun çikolatası online siparişimle ilgili herhangi bir sorun yaşamadım.
# Entity: Eti
# Expected Sentiment: nötr
# Predicted Sentiment: olumlu
# -----
# Input: Sek'in dondurması beklentilerimi karşılamadı, kalite kontrolü yetersizdi. Eti'nin meyve suyu online siparişim sorunsuz teslim edildi. Pınar'ın özel üretim bisküvisi lezzet açısından hayal kırıklığıydı. Torku'nun çikolatası online siparişimle ilgili herhangi bir sorun yaşamadım.
# Entity: Pınar
# Expected Sentiment: olumsuz
# Predicted Sentiment: olumsuz
# -----
# Input:
# Expected Sentiment: nötr
# Predicted Sentiment: olumsuz
# -----
# Input: Trendyol'dan aldığım giyim ürünleri beklentilerimi karşılamadı, kolay iade süreci sayesinde en azından ürün iadesini sorunsuz bir şekilde gerçekleştirebildim. N11'den kitap satın aldım, kitaplar kaliteliydi ancak bir önceki alışverişimle karşılaştırdığımda herhangi bir fark hissetmedim. GittiGidiyor'da ise kitap alışverişi yaparken güvenli ödeme seçenekleri bana güven verdi.
# Entity: GittiGidiyor
# Expected Sentiment: nötr
# Predicted Sentiment: olumlu
# -----
# Input: E-ticaret sitelerini denedikten sonra, Hepsiburada'dan kitap alırken kolay iade sürecinden memnun kaldım, fakat genel olarak nötr kaldım. Daha sonra N11'den ev eşyaları aldım ve güvenli ödeme seçenekleri sayesinde oldukça memnun kaldım. Amazon Türkiye'den de ev eşyaları almak istedim, fakat iade sürecinin kolay olmadığını düşünüyorum. Son olarak Trendyol'dan giyim ürünleri aldım ve kolay iade sürecinden memnun kaldım, fakat genel olarak nötr kaldım.
# Entity: Hepsiburada
# Expected Sentiment: nötr
# Predicted Sentiment: olumsuz
# -----
# Input: E-ticaret sitelerini denedikten sonra, Hepsiburada'dan kitap alırken kolay iade sürecinden memnun kaldım, fakat genel olarak nötr kaldım. Daha sonra N11'den ev eşyaları aldım ve güvenli ödeme seçenekleri sayesinde oldukça memnun kaldım. Amazon Türkiye'den de ev eşyaları almak istedim, fakat iade sürecinin kolay olmadığını düşünüyorum. Son olarak Trendyol'dan giyim ürünleri aldım ve kolay iade sürecinden memnun kaldım, fakat genel olarak nötr kaldım.
# Entity: N11
# Expected Sentiment: olumlu
# Predicted Sentiment: olumlu
# -----
# Input: E-ticaret sitelerini denedikten sonra, Hepsiburada'dan kitap alırken kolay iade sürecinden memnun kaldım, fakat genel olarak nötr kaldım. Daha sonra N11'den ev eşyaları aldım ve güvenli ödeme seçenekleri sayesinde oldukça memnun kaldım. Amazon Türkiye'den de ev eşyaları almak istedim, fakat iade sürecinin kolay olmadığını düşünüyorum. Son olarak Trendyol'dan giyim ürünleri aldım ve kolay iade sürecinden memnun kaldım, fakat genel olarak nötr kaldım.
# Entity: Amazon Türkiye
# Expected Sentiment: olumsuz
# Predicted Sentiment: olumsuz
# -----
# Input: E-ticaret sitelerini denedikten sonra, Hepsiburada'dan kitap alırken kolay iade sürecinden memnun kaldım, fakat genel olarak nötr kaldım. Daha sonra N11'den ev eşyaları aldım ve güvenli ödeme seçenekleri sayesinde oldukça memnun kaldım. Amazon Türkiye'den de ev eşyaları almak istedim, fakat iade sürecinin kolay olmadığını düşünüyorum. Son olarak Trendyol'dan giyim ürünleri aldım ve kolay iade sürecinden memnun kaldım, fakat genel olarak nötr kaldım.
# Entity: Trendyol
# Expected Sentiment: nötr
# Predicted Sentiment: olumsuz
# -----
# Input: Turknet'in fiber internet hizmeti sayesinde evimde hızlı ve güçlü bir bağlantıya sahip oldum. Ancak, Turkcell'in mobil hat tarifesini değiştirmeye çalıştığımda, bana uygun olmayan bir paket önerdiler ve tarife değişikliği işlemini gerçekleştiremediler. Türk Telekom'un müşteri desteği ise gerçekten kötüydü, bana yardımcı olmak yerine sadece bana soru sordu ve çözüm sunamadı.
# Entity: Turkcell
# Expected Sentiment: olumsuz
# Predicted Sentiment: nötr
# -----
# Input: Turknet'in fiber internet hizmeti sayesinde evimde hızlı ve güçlü bir bağlantıya sahip oldum. Ancak, Turkcell'in mobil hat tarifesini değiştirmeye çalıştığımda, bana uygun olmayan bir paket önerdiler ve tarife değişikliği işlemini gerçekleştiremediler. Türk Telekom'un müşteri desteği ise gerçekten kötüydü, bana yardımcı olmak yerine sadece bana soru sordu ve çözüm sunamadı.
# Entity: Türk Telekom
# Expected Sentiment: olumsuz
# Predicted Sentiment: olumlu
# -----
# Input: Turknet'in fiber internet hizmeti sayesinde evimde hızlı ve güçlü bir bağlantıya sahip oldum. Ancak, Turkcell'in mobil hat tarifesini değiştirmeye çalıştığımda, bana uygun olmayan bir paket önerdiler ve tarife değişikliği işlemini gerçekleştiremediler. Türk Telekom'un müşteri desteği ise gerçekten kötüydü, bana yardımcı olmak yerine sadece bana soru sordu ve çözüm sunamadı.
# Entity: Turknet
# Expected Sentiment: nötr
# Predicted Sentiment: olumlu
# -----
# Input:
# Expected Sentiment: olumsuz
# Predicted Sentiment: olumlu
# -----
# Input: Şirketlerimi gördüm, hepimiz Telekomünikasyon sektöründeyiz.
#
# Kullanmadığım TV+ için Turkcell müşteri desteğinden ilk defa yardım aldım, sonunda başaramadım, müşteri desteği hiç yardım etmek istemedi. Yakından baktım diğer rakip Vodafone müşteri desteği de hiç iyi gibi değil. Ama fark ettiğim Turknet customer destekleri diğer tüm şirketlere kıyasla gerçekten hakikaten yardımcı oldular. Vodafone için şöyle güzel bir gözlemim var. İhtiyacı olan müşterilerine sürekli olarak yurtdışı paketleri sunuyorlar. Yaptıkları satışlar da gerçekten hakikaten yerinde dedim de ben Vodafone için satın aldım, gerçekten yerinde.
# Entity: Turknet
# Expected Sentiment: olumlu
# Predicted Sentiment: olumlu
# -----
# Input: Şirketlerden memnunum demiş olayım.
#
# Telefon şarabı almam için Turkcell'e gittim, 4.5G hizmetleri ile ben harika buldum. Faturamı ödeyip cep telefonuma attım, problem yok. Turkcell'in fatura ödeme sistemi akıcıydi.
#
# Ama şirketten sonra Superonline'e gittim. Akıllı ev çözümleri ile arada fark var, farklı. Yurtdışı paketlerini daha iyi düşündükten sonra kullanacağım dedim.  Şimdi sırada kuyruktur.
# Entity: Turkcell
# Expected Sentiment: olumlu
# Predicted Sentiment: olumlu
# -----
# Input: Şirketlerden memnunum demiş olayım.
#
# Telefon şarabı almam için Turkcell'e gittim, 4.5G hizmetleri ile ben harika buldum. Faturamı ödeyip cep telefonuma attım, problem yok. Turkcell'in fatura ödeme sistemi akıcıydi.
#
# Ama şirketten sonra Superonline'e gittim. Akıllı ev çözümleri ile arada fark var, farklı. Yurtdışı paketlerini daha iyi düşündükten sonra kullanacağım dedim.  Şimdi sırada kuyruktur.
# Entity: Superonline
# Expected Sentiment: nötr
# Predicted Sentiment: nötr
# -----
# Input: Pegasus'te ekonomi sınıfı bilet kullandım, ancak lounge erişimi sadece üst sınıf için geçerliydi. Türk Hava Yolları'nın transfer hizmetleri hem iyi hem de güvenliydi. Ancak AnadoluJet'in transfer hizmetleri daha fazla bekleme gerektirdi. Onur Air, seçeneklerin azlığı nedeniyle benim için iyi bir deneyim olmadı.
# Entity: Pegasus
# Expected Sentiment: olumsuz
# Predicted Sentiment: olumlu
# -----
# Input: Pegasus'te ekonomi sınıfı bilet kullandım, ancak lounge erişimi sadece üst sınıf için geçerliydi. Türk Hava Yolları'nın transfer hizmetleri hem iyi hem de güvenliydi. Ancak AnadoluJet'in transfer hizmetleri daha fazla bekleme gerektirdi. Onur Air, seçeneklerin azlığı nedeniyle benim için iyi bir deneyim olmadı.
# Entity: Türk Hava Yolları
# Expected Sentiment: nötr
# Predicted Sentiment: nötr
# -----
# Input: Pegasus'te ekonomi sınıfı bilet kullandım, ancak lounge erişimi sadece üst sınıf için geçerliydi. Türk Hava Yolları'nın transfer hizmetleri hem iyi hem de güvenliydi. Ancak AnadoluJet'in transfer hizmetleri daha fazla bekleme gerektirdi. Onur Air, seçeneklerin azlığı nedeniyle benim için iyi bir deneyim olmadı.
# Entity: AnadoluJet
# Expected Sentiment: nötr
# Predicted Sentiment: olumlu
# -----
# Input: Pegasus'te ekonomi sınıfı bilet kullandım, ancak lounge erişimi sadece üst sınıf için geçerliydi. Türk Hava Yolları'nın transfer hizmetleri hem iyi hem de güvenliydi. Ancak AnadoluJet'in transfer hizmetleri daha fazla bekleme gerektirdi. Onur Air, seçeneklerin azlığı nedeniyle benim için iyi bir deneyim olmadı.
# Entity: Onur Air
# Expected Sentiment: nötr
# Predicted Sentiment: nötr
# -----
# Input: Onur Air ile yaptığım son uçuşta, özel menü seçenekleri gerçekten etkileyiciydi. Uçuş değişikliği konusunda da oldukça esnek davrandılar.
#
# AnadoluJet'in ekstra bagaj hakkı ve lounge erişimi, seyahat deneyimimi bir üst seviyeye taşıdı.
#
# Türk Hava Yolları'nın özel menü seçenekleri ve lounge erişimi, uçuşumu gerçekten keyifli hale getirdi.
# Entity: Onur Air
# Expected Sentiment: olumlu
# Predicted Sentiment: olumlu
# -----
# Input: Onur Air ile yaptığım son uçuşta, özel menü seçenekleri gerçekten etkileyiciydi. Uçuş değişikliği konusunda da oldukça esnek davrandılar.
#
# AnadoluJet'in ekstra bagaj hakkı ve lounge erişimi, seyahat deneyimimi bir üst seviyeye taşıdı.
#
# Türk Hava Yolları'nın özel menü seçenekleri ve lounge erişimi, uçuşumu gerçekten keyifli hale getirdi.
# Entity: AnadoluJet
# Expected Sentiment: olumlu
# Predicted Sentiment: olumlu
# -----
# Input: Onur Air ile yaptığım son uçuşta, özel menü seçenekleri gerçekten etkileyiciydi. Uçuş değişikliği konusunda da oldukça esnek davrandılar.
#
# AnadoluJet'in ekstra bagaj hakkı ve lounge erişimi, seyahat deneyimimi bir üst seviyeye taşıdı.
#
# Türk Hava Yolları'nın özel menü seçenekleri ve lounge erişimi, uçuşumu gerçekten keyifli hale getirdi.
# Entity: Türk Hava Yolları
# Expected Sentiment: olumlu
# Predicted Sentiment: olumlu
# -----
# Input: AnadoluJet'in business sınıfı biletini aldım ama online check-in'de yaşadığım sorunlar nedeniyle uçuşumu kaçırdım, çok hayal kırıklığına uğradım. Onur Air'den business sınıfı bilet aldım, uçuş değişikliği yapmam gerektiğinde yardımcı oldular ama beklentilerim tam olarak karşılanmadı. Türk Hava Yolları'nın ekonomi sınıfı biletini kullandım, transfer hizmetleri iyi organize edilmişti ama beklentilerim yüksek değildi. Pegasus'un ekstra bagaj hakkını aldım ve uçuş değişikliği yapmam gerektiğinde çok yardımcı oldular, memnun kaldım.
# Entity: AnadoluJet
# Expected Sentiment: olumsuz
# Predicted Sentiment: olumlu
# -----
# Input: AnadoluJet'in business sınıfı biletini aldım ama online check-in'de yaşadığım sorunlar nedeniyle uçuşumu kaçırdım, çok hayal kırıklığına uğradım. Onur Air'den business sınıfı bilet aldım, uçuş değişikliği yapmam gerektiğinde yardımcı oldular ama beklentilerim tam olarak karşılanmadı. Türk Hava Yolları'nın ekonomi sınıfı biletini kullandım, transfer hizmetleri iyi organize edilmişti ama beklentilerim yüksek değildi. Pegasus'un ekstra bagaj hakkını aldım ve uçuş değişikliği yapmam gerektiğinde çok yardımcı oldular, memnun kaldım.
# Entity: Onur Air
# Expected Sentiment: nötr
# Predicted Sentiment: olumsuz
# -----
# Input: AnadoluJet'in business sınıfı biletini aldım ama online check-in'de yaşadığım sorunlar nedeniyle uçuşumu kaçırdım, çok hayal kırıklığına uğradım. Onur Air'den business sınıfı bilet aldım, uçuş değişikliği yapmam gerektiğinde yardımcı oldular ama beklentilerim tam olarak karşılanmadı. Türk Hava Yolları'nın ekonomi sınıfı biletini kullandım, transfer hizmetleri iyi organize edilmişti ama beklentilerim yüksek değildi. Pegasus'un ekstra bagaj hakkını aldım ve uçuş değişikliği yapmam gerektiğinde çok yardımcı oldular, memnun kaldım.
# Entity: Türk Hava Yolları
# Expected Sentiment: nötr
# Predicted Sentiment: olumsuz
# -----
# Input
# Expected Sentiment: nötr
# Predicted Sentiment: nötr
# -----
# Input: Tabii ki! İşte müşteri yorumları:
#
# Turkcell ile başladığımızda Mobil hattıma kavuşuyorduk. Ancak online işlemlerableyince bazı sıkıntılar yaşıyoruz. Nötr kal>*</ yorumum bu.
#
# Bir ara ev telefonum için Turknet'e geçtim ve eminim ki bu kararımın en büyük nedeni online işlemleriydi! Çok kolay ve hızlı bir sistem. Olumlu bir yaşantım ve tamamen memnun kaldım.
#
# Turkcell ile başladığımızda Mobil hattıma kavuşuyorduk. Ancak online işlemlerableyince bazı sıkıntılar yaşıyoruz. Nötr kal *</ yorumum bu. Vodafone Türkiye geldi. 4.5G hizmetleriyle impress olduğumu söylemeliyim! Yurtdışı paketlerini de çok beğendim. Olumlu kalmış durumdaim.
# Entity: Turkcell
# Expected Sentiment: nötr
# Predicted Sentiment: nötr
# -----
# Input: Tabii ki! İşte müşteri yorumları:
#
# Turkcell ile başladığımızda Mobil hattıma kavuşuyorduk. Ancak online işlemlerableyince bazı sıkıntılar yaşıyoruz. Nötr kal>*</ yorumum bu.
#
# Bir ara ev telefonum için Turknet'e geçtim ve eminim ki bu kararımın en büyük nedeni online işlemleriydi! Çok kolay ve hızlı bir sistem. Olumlu bir yaşantım ve tamamen memnun kaldım.
#
# Turkcell ile başladığımızda Mobil hattıma kavuşuyorduk. Ancak online işlemlerableyince bazı sıkıntılar yaşıyoruz. Nötr kal *</ yorumum bu. Vodafone Türkiye geldi. 4.5G hizmetleriyle impress olduğumu söylemeliyim! Yurtdışı paketlerini de çok beğendim. Olumlu kalmış durumdaim.
# Entity: Turknet
# Expected Sentiment: olumlu
# Predicted Sentiment: olumlu
# -----
# Input: Tabii ki! İşte müşteri yorumları:
#
# Turkcell ile başladığımızda Mobil hattıma kavuşuyorduk. Ancak online işlemlerableyince bazı sıkıntılar yaşıyoruz. Nötr kal>*</ yorumum bu.
#
# Bir ara ev telefonum için Turknet'e geçtim ve eminim ki bu kararımın en büyük nedeni online işlemleriydi! Çok kolay ve hızlı bir sistem. Olumlu bir yaşantım ve tamamen memnun kaldım.
#
# Turkcell ile başladığımızda Mobil hattıma kavuşuyorduk. Ancak online işlemlerableyince bazı sıkıntılar yaşıyoruz. Nötr kal *</ yorumum bu. Vodafone Türkiye geldi. 4.5G hizmetleriyle impress olduğumu söylemeliyim! Yurtdışı paketlerini de çok beğendim. Olumlu kalmış durumdaim.
# Entity: Vodafone Türkiye
# Expected Sentiment: olumlu
# Predicted Sentiment: olumlu
# -----
# Input: Çiçeksepeti'nden kozmetik ürünleri aldım ama müşteri yorumlarındaki gibi iyi değildi. Ürünü iade etmek istedim ama müşteri hizmetleri çok yavaş cevap verdi. N11'den spor malzemeleri aldım, güvenli ödeme yöntemleri iyi ama ürünler biraz pahalı.
# Entity: Çiçeksepeti
# Expected Sentiment: olumsuz
# Predicted Sentiment: olumsuz
# -----
# Input: Çiçeksepeti'nden kozmetik ürünleri aldım ama müşteri yorumlarındaki gibi iyi değildi. Ürünü iade etmek istedim ama müşteri hizmetleri çok yavaş cevap verdi. N11'den spor malzemeleri aldım, güvenli ödeme yöntemleri iyi ama ürünler biraz pahalı.
# Entity: N11
# Expected Sentiment: nötr
# Predicted Sentiment: olumlu
# -----
# Input: N11'de aldığım ev eşyası çok gerne uyduyordu, sonucta sık sık kullanıyorum. Farklı birçok markaya ulaştım ve kolay iade hizmeti olması da çok iyi. Trendyol'dan ne yazık ki çok kötü deneyimler yaşadım, indirim kuponlarının çoğu işlemedi. Hepsiburada'yı kullanıyorum ama spor malzemesi alırken hızlı ödeme hizmeti vermesi beni çok memnun etti. İlk deneyimimle memnun kaldıkça deneyimliyorum. Çiçeksepeti.net de ev eşyası aldım ama iadeye kadar olan süreçte çok olumsuz sonuçlar elde ettim.
# Entity: N11
# Expected Sentiment: nötr
# Predicted Sentiment: olumsuz
# -----
# Input
# Expected Sentiment: nötr
# Predicted Sentiment: olumlu
# -----
# Input: Vodafone Türkiye'nin akıllı ev çözümleri konusunda hiç yanlış yoktu. Kullanışlı online işlemler ve kolay destek, seçiminizi kolaylaştırıyordu. Benim için ideal bir şirket oldu, son olarak tavsiyemi verebilirim. Öte yandan, Turkcell'in 4.5G hizmetleri de iyi performansa sahipti. Online işlemleri de düzgün işliyordu ama biraz daha yüksek ücretlerinden rahatsız oldum. Hesabımı kapattım, orta yerine daha iyi bir seçenek bulunduğunu gördüm.
# Entity: Vodafone Türkiye
# Expected Sentiment: olumlu
# Predicted Sentiment: nötr
# -----
# Input: Vodafone Türkiye'nin akıllı ev çözümleri konusunda hiç yanlış yoktu. Kullanışlı online işlemler ve kolay destek, seçiminizi kolaylaştırıyordu. Benim için ideal bir şirket oldu, son olarak tavsiyemi verebilirim. Öte yandan, Turkcell'in 4.5G hizmetleri de iyi performansa sahipti. Online işlemleri de düzgün işliyordu ama biraz daha yüksek ücretlerinden rahatsız oldum. Hesabımı kapattım, orta yerine daha iyi bir seçenek bulunduğunu gördüm.
# Entity: Turkcell
# Expected Sentiment: nötr
# Predicted Sentiment: nötr
# -----
# Input: Pegasus uçuş değişikliği için mil programları beni çok kolayca memnun etti. Tıkla ve değişikliği yap. Süper Pratik!
#
# Onur Air'den en son ekstra bagaj hakkı almayı çok sevdim. Uçuş değişikliği için aldığım hizmet çok hızlı ve sorun çıkarmadan gerçekleşti. Onur Air çok iyi şirket!
# Entity: Pegasus
# Expected Sentiment: olumlu
# Predicted Sentiment: nötr
# -----
# Input: Pegasus uçuş değişikliği için mil programları beni çok kolayca memnun etti. Tıkla ve değişikliği yap. Süper Pratik!
#
# Onur Air'den en son ekstra bagaj hakkı almayı çok sevdim. Uçuş değişikliği için aldığım hizmet çok hızlı ve sorun çıkarmadan gerçekleşti. Onur Air çok iyi şirket!
# Entity: Onur Air
# Expected Sentiment: olumlu
# Predicted Sentiment: olumlu
# -----
# Input: Pınar'ın bisküvileri sayesinde yediğim ilk Türkiye bisküvisiydi ve sonrasına bakmadım. Kalite kontrolü ve enfes tadı ile pazarda en iyisi. Pınar'a en şiddetli 5 yıldız verdım.
#
# Ama Pınar ile mi karşılaştırmacıyım? Ben Ülker'in ise sunduğu sütünle bile hep mutlu oluyorum. Ürün çeşitliliğine sahip olduğu için hep farklı seçeneklere imdadlar. Yaptıkları adımlar ile hep destekıyoruz.
#
# Bilmek istedim Ulkerin ulasıncagina ne kadar büyük ürün yelpazesına sahip ise ki herkezesinde alıcaklıyız. Fakat bisküviler için bir başlangıç yaptık ve hepimize yeni bir zamanları başlar. Dimes ile mi kaldı? Bana göre online sipariş alma da çok hoşum oldu.
# Entity: Pınar
# Expected Sentiment: olumlu
# Predicted Sentiment: olumlu
# -----
# Input: Pınar'ın bisküvileri sayesinde yediğim ilk Türkiye bisküvisiydi ve sonrasına bakmadım. Kalite kontrolü ve enfes tadı ile pazarda en iyisi. Pınar'a en şiddetli 5 yıldız verdım.
#
# Ama Pınar ile mi karşılaştırmacıyım? Ben Ülker'in ise sunduğu sütünle bile hep mutlu oluyorum. Ürün çeşitliliğine sahip olduğu için hep farklı seçeneklere imdadlar. Yaptıkları adımlar ile hep destekıyoruz.
#
# Bilmek istedim Ulkerin ulasıncagina ne kadar büyük ürün yelpazesına sahip ise ki herkezesinde alıcaklıyız. Fakat bisküviler için bir başlangıç yaptık ve hepimize yeni bir zamanları başlar. Dimes ile mi kaldı? Bana göre online sipariş alma da çok hoşum oldu.
# Entity: Ülker
# Expected Sentiment: olumlu
# ...
# Entity: Vodafone Türkiye
# Expected Sentiment: olumlu
# Expected Sentiment: olumsuz
# Predicted Sentiment: olumsuz
# -----
# Input: Yapı Kredi'nin Investment fonu uzun vadede kayıp yaşattığını, mobil bankacılık uygulamasının arayüzünün karmaşık olduğunu düşünüyorum. Bununla birlikte Akbank'nın bireysel emeklilik planı doğru seçilmiş gibi görünse de şube işlemlerinde beklediğim hız yok.
# Entity: Akbank
# Expected Sentiment: nötr
# Predicted Sentiment: olumsuz
# -----
# Input: Turkcell'de ev telefonu sayaçlarını düzenlemeye çalıştım ama çok uzun bir süre kırmızıya çıktı. eventually, müşteri desteğinde çözüme ulaştım ama zaman kaybedildi.
# Turknet TV+ ile ise deneyimim kesinlikle daha farklıydı. Herşeyi online olarak hallettim ve sorunsuz bir şekilde kullanıyorum.
# Entity: Turknet
# Expected Sentiment: olumlu
# Predicted Sentiment: olumlu
# -----
# Input: Turkcell'de ev telefonu sayaçlarını düzenlemeye çalıştım ama çok uzun bir süre kırmızıya çıktı. eventually, müşteri desteğinde çözüme ulaştım ama zaman kaybedildi.
# Turknet TV+ ile ise deneyimim kesinlikle daha farklıydı. Herşeyi online olarak hallettim ve sorunsuz bir şekilde kullanıyorum.
# Entity: Turkcell
# Expected Sentiment: nötr
# Predicted Sentiment: nötr
# -----
# Input: Evim için akıllı ev çözümleri araştırıyordum, Turk Telekom'un hizmetinden memnun kaldım ancak fatura ödeme aşamasında bazı aksaklıklar yaşadım, şirketi bu anlamda nötr olarak değerlendiriyorum.
#
# Önceden Superonline'nin fiber internet abonesiydim, ne yazık ki müşteri desteğinden büyük sıkıntı yaşadım ve.service kalitesine bir şey diyemiyorum. Ben şimdi Superonline kullandığım icin bi secimi oldu simdi onun  icin bana aciması
#
# Evinde sabit telefon ihtiyacı için Vodafone'u tercih ediyorum. Başta karşımda profesyonelliği gördüğüm müşteri temsilcisinin verdiği sözü tuttu. Beklentilerimin çok ötesinde ev telefonum hizmetim, yardımcı oldukları ve çözümü olan profesyonel kişiler. Kaliteden yana gerçekten erfolgre customer hizmetine sahiptir, diye dısbıtasyon secıyorum şimdi .
#
# Fiber internet ihtiyacımı Turknet sayesinde gideriyorum, internet hızı çok başarılı, ayrıca online işlemleride son derece basit. Sektördeki şirketlerle kıyaslayacak olursam internet hızı en güçlü, internet faturalandırma ile arıtmalarında gösterdikleri hızlı yöntemleri oldugu ıcınde gercekte onnum bana goz atısı
#
# Acayip iciniz.
# Entity: Türk Telekom
# Expected Sentiment: nötr
# Predicted Sentiment: olumlu
# -----
# Input: Evim için akıllı ev çözümleri araştırıyordum, Turk Telekom'un hizmetinden memnun kaldım ancak fatura ödeme aşamasında bazı aksaklıklar yaşadım, şirketi bu anlamda nötr olarak değerlendiriyorum.
#
# Önceden Superonline'nin fiber internet abonesiydim, ne yazık ki müşteri desteğinden büyük sıkıntı yaşadım ve.service kalitesine bir şey diyemiyorum. Ben şimdi Superonline kullandığım icin bi secimi oldu simdi onun  icin bana aciması
#
# Evinde sabit telefon ihtiyacı için Vodafone'u tercih ediyorum. Başta karşımda profesyonelliği gördüğüm müşteri temsilcisinin verdiği sözü tuttu. Beklentilerimin çok ötesinde ev telefonum hizmetim, yardımcı oldukları ve çözümü olan profesyonel kişiler. Kaliteden yana gerçekten erfolgre customer hizmetine sahiptir, diye dısbıtasyon secıyorum şimdi .
#
# Fiber internet ihtiyacımı Turknet sayesinde gideriyorum, internet hızı çok başarılı, ayrıca online işlemleride son derece basit. Sektördeki şirketlerle kıyaslayacak olursam internet hızı en güçlü, internet faturalandırma ile arıtmalarında gösterdikleri hızlı yöntemleri oldugu ıcınde gercekte onnum bana goz atısı
#
# Acayip iciniz.
# Entity: Superonline
# Expected Sentiment: olumsuz
# Predicted Sentiment: olumlu
# -----
# Input: Evim için akıllı ev çözümleri araştırıyordum, Turk Telekom'un hizmetinden memnun kaldım ancak fatura ödeme aşamasında bazı aksaklıklar yaşadım, şirketi bu anlamda nötr olarak değerlendiriyorum.
#
# Önceden Superonline'nin fiber internet abonesiydim, ne yazık ki müşteri desteğinden büyük sıkıntı yaşadım ve.service kalitesine bir şey diyemiyorum. Ben şimdi Superonline kullandığım icin bi secimi oldu simdi onun  icin bana aciması
#
# Evinde sabit telefon ihtiyacı için Vodafone'u tercih ediyorum. Başta karşımda profesyonelliği gördüğüm müşteri temsilcisinin verdiği sözü tuttu. Beklentilerimin çok ötesinde ev telefonum hizmetim, yardımcı oldukları ve çözümü olan profesyonel kişiler. Kaliteden yana gerçekten erfolgre customer hizmetine sahiptir, diye dısbıtasyon secıyorum şimdi .
#
# Fiber internet ihtiyacımı Turknet sayesinde gideriyorum, internet hızı çok başarılı, ayrıca online işlemleride son derece basit. Sektördeki şirketlerle kıyaslayacak olursam internet hızı en güçlü, internet faturalandırma ile arıtmalarında gösterdikleri hızlı yöntemleri oldugu ıcınde gercekte onnum bana goz atısı
#
# Acayip iciniz.
# Entity: Vodafone Türkiye
# Expected Sentiment: olumlu
# Predicted Sentiment: olumlu
# -----
# Input: Evim için akıllı ev çözümleri araştırıyordum, Turk Telekom'un hizmetinden memnun kaldım ancak fatura ödeme aşamasında bazı aksaklıklar yaşadım, şirketi bu anlamda nötr olarak değerlendiriyorum.
#
# Önceden Superonline'nin fiber internet abonesiydim, ne yazık ki müşteri desteğinden büyük sıkıntı yaşadım ve.service kalitesine bir şey diyemiyorum. Ben şimdi Superonline kullandığım icin bi secimi oldu simdi onun  icin bana aciması
#
# Evinde sabit telefon ihtiyacı için Vodafone'u tercih ediyorum. Başta karşımda profesyonelliği gördüğüm müşteri temsilcisinin verdiği sözü tuttu. Beklentilerimin çok ötesinde ev telefonum hizmetim, yardımcı oldukları ve çözümü olan profesyonel kişiler. Kaliteden yana gerçekten erfolgre customer hizmetine sahiptir, diye dısbıtasyon secıyorum şimdi .
#
# Fiber internet ihtiyacımı Turknet sayesinde gideriyorum, internet hızı çok başarılı, ayrıca online işlemleride son derece basit. Sektördeki şirketlerle kıyaslayacak olursam internet hızı en güçlü, internet faturalandırma ile arıtmalarında gösterdikleri hızlı yöntemleri oldugu ıcınde gercekte onnum bana goz atısı
#
# Acayip iciniz.
# Entity: Turknet
# Expected Sentiment: olumlu
# Predicted Sentiment: olumlu
# -----
# Total Entities: 1317
# Correct Entities: 1199
# Correct Sentiments: 655
# Entity Recognition Accuracy: 91.04%
# Sentiment Analysis Accuracy: 49.73%
